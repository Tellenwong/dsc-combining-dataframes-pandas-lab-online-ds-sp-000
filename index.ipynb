# %% [markdown]
# # Combining DataFrames With Pandas - Lab
#
# ## Introduction
#
# In this lab, you'll gain practice combining DataFrames through concatenation.  You'll also practice executing various types of joins to selectively combine the information stored in the tables!
#
# ## Objectives
#
# In this lab you will:
#
# - Use concatenation to combine DataFrames
# - Determine which type of join is preferred for two tables of data and a task
# - Use different types of joins to merge dataframes
#
#
# ## Concatenating DataFrames
#
# Run the cell below to create some sample DataFrames for us to work with.

# %%
import pandas as pd
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3'],
                    'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']},
                    index=[0, 1, 2, 3])


df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                    'B': ['B4', 'B5', 'B6', 'B7'],
                    'C': ['C4', 'C5', 'C6', 'C7'],
                    'D': ['D4', 'D5', 'D6', 'D7']},
                    index=[4, 5, 6, 7])

df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                    'B': ['B8', 'B9', 'B10', 'B11'],
                    'C': ['C8', 'C9', 'C10', 'C11'], 
                    'D': ['D8', 'D9', 'D10', 'D11']},
                    index=[8, 9, 10, 11])

# %% [markdown]
# Now that you have multiple DataFrames to work with, you can execute a concatenation to join them together.
#
# In the cell below, concatenate the 3 DataFrames together using the appropriate function.

# %%
combined_df = pd.concat([df1,df2,df3])
combined_df
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %% [markdown]
# **_EXPECTED OUTPUT:_**
#
# <img src="images/er1.png">
#
# ## Setting join conditions with concatenation
#
# You can also specify if the concatenation is an **_Outer Join_** or an **_Inner Join_**.  Next, you'll execute an inner join. Before you do, you need to create another table that contains some overlapping index values with a DataFrame that already exists.
#
# Run the cell below to create the new DataFrame.

# %%
df4 = pd.DataFrame({'B': ['B2', 'B3', 'B6', 'B7'],
                    'D': ['D2', 'D3', 'D6', 'D7'],
                    'F': ['F2', 'F3', 'F6', 'F7']},
                    index=[2, 3, 6, 7])

# %% [markdown]
# Now, in the cell below, use the `pd.concat()` function to join DataFrames 1 and 4.  However, this time, specify that the `join` is `'inner'`, and `axis=1`.

# %%
df1_and_4 = pd.concat([df1,df4], join = 'inner', axis = 1)
df1_and_4
# Out:
#     A   B   C   D   B   D   F
# 2  A2  B2  C2  D2  B2  D2  F2
# 3  A3  B3  C3  D3  B3  D3  F3

# %% [markdown]
# **_EXPECTED OUTPUT:_**
#
# <img src='images/er2.png'>
#
# You'll notice that in this case, the results contain only the rows with indexes that exist in both tables -- rows 2 and 3.  The resulting table contains the values for each column in both tables for the rows.
#
# Note that there are many, many ways that you can make full use of the `pd.concat()` function in pandas to join DataFrames together -- these are just a few of the most common examples pulled from the pandas documentation on the subject. For a full view of all the ways you can use `pd.concat()`, see the [pandas documentation](http://pandas.pydata.org/pandas-docs/stable/merging.html)!
#
# ## Load data
# Now, it's time to move on to working with the Hearthstone cards database.  This database contains information on cards from the popular game, [Hearthstone](https://playhearthstone.com/en-us/)! For full information on the dataset, see the [Kaggle page](https://www.kaggle.com/jeradrose/hearthstone-cards) for this dataset.
#
# This database consists of the following tables:
#
# * _cards_
# * *dust_costs*
# * _entourages_
# * _mechanics_
# * *play_requirements*
#
# Many of rows in each table -- but not all -- correspond to the same cards. As such, each table contains a column called `card_id` which acts as a **_Primary Key_** for each table.  You'll make use of these keys to **_join_** the different tables together into a single DataFrame. You'll also experiment with different types of joins to help us decide exactly what information you wish to combine.
#
# Simply run the cell below to import the tables from the database as DataFrames.

# %%
cards_df = pd.read_csv('cards.csv')
dust_df = pd.read_csv('dust.csv')
entourages_df = pd.read_csv('entourages.csv')
mechanics_df = pd.read_csv('mechanics.csv')
play_requirements_df = pd.read_csv('play_requirements.csv')

# %% [markdown]
# Great.  Now, let's set the correct column, `card_id`, as the index column for each of these tables, and then display each to ensure that everything is as expected.
#
# For each of the DataFrames you created in the cell above, call the `.set_index()` method and pass in `card_id`.  Also set `inplace=True`.  Then, display the `.head()` of each respective DataFrame to ensure everything worked.
#
# **_NOTE:_** Since you are performing this operation in place, running any cell a second time will result in pandas throwing an error.  If you need to run something a second time, restart the kernel using the jupyter notebook menu at the top of the page.

# %%
cards_df.set_index(cards_df.card_id, inplace=True)
cards_df.head()
# Out:
#                card_id player_class    type                name      set  \
# card_id
# KARA_00_07  KARA_00_07         MAGE   SPELL       Astral Portal     KARA
# NEW1_008a    NEW1_008a        DRUID   SPELL   Ancient Teachings  EXPERT1
# BRM_010t2    BRM_010t2        DRUID  MINION  Druid of the Flame      BRM
# AT_132          AT_132      NEUTRAL  MINION  Justicar Trueheart      TGT
# OG_141          OG_141      NEUTRAL  MINION   Faceless Behemoth       OG
#
#                                                          text  cost  attack  \
# card_id
# KARA_00_07           Summon a random <b>Legendary</b> minion.   1.0     NaN
# NEW1_008a                                        Draw a card.   0.0     NaN
# BRM_010t2                                                 NaN   3.0     2.0
# AT_132      <b>Battlecry:</b> Replace your starting Hero P...   6.0     6.0
# OG_141                                                    NaN  10.0    10.0
#
#             health     rarity  collectible  \
# card_id
# KARA_00_07     NaN        NaN          NaN
# NEW1_008a      NaN        NaN          NaN
# BRM_010t2      5.0     COMMON          NaN
# AT_132         3.0  LEGENDARY          1.0
# OG_141        10.0     COMMON          1.0
#
#                                                        flavor   race  \
# card_id
# KARA_00_07                                                NaN    NaN
# NEW1_008a                                                 NaN    NaN
# BRM_010t2                                                 NaN  BEAST
# AT_132      It's like putting racing stripes and a giant s...    NaN
# OG_141      Rejected names: Forty-Foot Faceless, Big ol' N...    NaN
#
#            how_to_earn how_to_earn_golden targeting_arrow_text faction  \
# card_id
# KARA_00_07         NaN                NaN                  NaN     NaN
# NEW1_008a          NaN                NaN                  NaN     NaN
# BRM_010t2          NaN                NaN                  NaN     NaN
# AT_132             NaN                NaN                  NaN     NaN
# OG_141             NaN                NaN                  NaN     NaN
#
#             durability
# card_id
# KARA_00_07         NaN
# NEW1_008a          NaN
# BRM_010t2          NaN
# AT_132             NaN
# OG_141             NaN

# %%
dust_df.set_index(dust_df.card_id, inplace=True)

# %%
entourages_df.set_index(entourages_df.card_id, inplace=True)

# %%
mechanics_df.set_index('card_id', inplace=True)

# %%
play_requirements_df.set_index('card_id', inplace=True)

# %% [markdown]
# ## Executing Joins
#
# Now that you have the tables loaded correctly, we're going to execute some joins. There are four different kinds of joins, which can best be visualized with Venn diagrams:
#
# <img src='images/Image_198_joins.png'>
#
# In these diagrams, each circle represents a DataFrame or SQL Table. The left table is the table you are working with, and the right table is the table you want to join to the table you are working with. You'll start by executing the most common type of join, an **_Inner Join_**.
#
# In the cell below, join `cards_df` with `mechanics_df` using the built-in `.join()` method on the `cards_df` object.
#
# Pass in the following parameters:
# * the table you want to join with, `mechanics_df`
# * The `how` parameter set to the type of join you want, `'inner'`

# %%
cards_with_mechanics_df = cards_df.join(mechanics_df, how = 'inner')
cards_with_mechanics_df.head()
# Out:
# Empty DataFrame
# Columns: [card_id, player_class, type, name, set, text, cost, attack, health, rarity, collectible, flavor, race, how_to_earn, how_to_earn_golden, targeting_arrow_text, faction, durability, mechanic]
# Index: []

# %% [markdown]
# Examine the output from the cell above and compare it to the original output of both the `cards_df` and `mechanics_df` DataFrame heads you displayed earlier.  Notice how this now combines the columns from both?
#
# **_Question_**
#
# If you inspect the original `cards_df` DataFrame, you'll notice that it contains  2,819 records.  The result of our inner join, `cards_with_mechanics_df`, contains only 1079 rows.  Why?
#
# Write your answer below this line:
# ________________________________________________________________________________
# Inner joins only join together records that are present in both data tables. The 2 tables only had 1079 records in common.

# %% [markdown]
# ## Other Types of Joins
#
# By default, the `.join()` method performs a left join if no parameter is passed in for `how=`.  In the cell below, perform a **_Left Join_** of `cards_with_mechanics_df` and `play_requirements_df`, with `cards_with_mechanics_df` as the left table.
#
# Then, display `left_join_df` to inspect our results.

# %%
left_join_df = cards_with_mechanics_df.join(play_requirements_df)
left_join_df
# Out:
# Empty DataFrame
# Columns: [card_id, player_class, type, name, set, text, cost, attack, health, rarity, collectible, flavor, race, how_to_earn, how_to_earn_golden, targeting_arrow_text, faction, durability, mechanic, play_requirement, value]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# Note that the results of this sort of join are dependent upon the position of each table--if you were to make `cards_with_mechanics_df` the right table and `play_requirements_df` the left table and then perform a **_Right Join_**, our results would be the same.
#
# **_Question:_**
#
# Describe what was included from each table in this join.
#
# Write your answer below this line:
# # Every record from cards_with_mechanics_df, as well as any records from play_requirements_df that have matching index values
# # with a record from the left table.
# ________________________________________________________________________________

# %% [markdown]
# #### Outer Joins
#
# In the cell below, perform an outer join between `cards_df` and `dust_df`. Since these tables contain columns with the same name, we'll need to specify a suffix for at least one of them, so that the column can be renamed to avoid a naming collision.
#
# During this join, set the `rsuffix` parameter to `_dust`

# %%
outer_join_df = cards_df.join(dust_df, how = 'outer', rsuffix = '_dust')
outer_join_df
# Out:
#                           card_id player_class         type  \
# 0                      KARA_00_07         MAGE        SPELL
# 1                       NEW1_008a        DRUID        SPELL
# 2                       BRM_010t2        DRUID       MINION
# 3                          AT_132      NEUTRAL       MINION
# 4                          OG_141      NEUTRAL       MINION
# 5                         CRED_17      NEUTRAL       MINION
# 6                         OG_337e      NEUTRAL  ENCHANTMENT
# 7                       BRMA08_1H      NEUTRAL         HERO
# 8                        GVG_011a      NEUTRAL  ENCHANTMENT
# 9                     NAX8_02H_TB      NEUTRAL   HERO_POWER
# 10                         AT_131      NEUTRAL       MINION
# 11                       CS2_122e      NEUTRAL  ENCHANTMENT
# 12                    LOEA05_02ha      NEUTRAL   HERO_POWER
# 13              CS2_102_H1_AT_132      WARRIOR   HERO_POWER
# 14                       CFM_334e      NEUTRAL  ENCHANTMENT
# 15                        EX1_583      NEUTRAL       MINION
# 16         TB_PickYourFate_11rand      NEUTRAL        SPELL
# 17                       LOE_007t      WARLOCK        SPELL
# 18                        CFM_095      NEUTRAL       MINION
# 19                        BRM_018      PALADIN       MINION
# 20                       PRO_001a      NEUTRAL        SPELL
# 21                      BRMA10_5H      NEUTRAL       MINION
# 22                       BRMA11_1      NEUTRAL         HERO
# 23                         OG_027       SHAMAN        SPELL
# 24                        NAX1_01      NEUTRAL         HERO
# 25                        GVG_030        DRUID       MINION
# 26                        CFM_094      WARLOCK        SPELL
# 27                    DS1h_292_H1       HUNTER   HERO_POWER
# 28                        CS2_227      NEUTRAL       MINION
# 29                        KAR_062      NEUTRAL       MINION
# ...                           ...          ...          ...
# OG_338                        NaN          NaN          NaN
# OG_338                        NaN          NaN          NaN
# OG_339                        NaN          NaN          NaN
# OG_339                        NaN          NaN          NaN
# OG_339                        NaN          NaN          NaN
# OG_339                        NaN          NaN          NaN
# OG_340                        NaN          NaN          NaN
# OG_340                        NaN          NaN          NaN
# OG_340                        NaN          NaN          NaN
# OG_340                        NaN          NaN          NaN
# TB_OG_027                     NaN          NaN          NaN
# TB_OG_027                     NaN          NaN          NaN
# TB_OG_027                     NaN          NaN          NaN
# TB_OG_027                     NaN          NaN          NaN
# skele21                       NaN          NaN          NaN
# skele21                       NaN          NaN          NaN
# skele21                       NaN          NaN          NaN
# skele21                       NaN          NaN          NaN
# tt_004                        NaN          NaN          NaN
# tt_004                        NaN          NaN          NaN
# tt_004                        NaN          NaN          NaN
# tt_004                        NaN          NaN          NaN
# tt_010                        NaN          NaN          NaN
# tt_010                        NaN          NaN          NaN
# tt_010                        NaN          NaN          NaN
# tt_010                        NaN          NaN          NaN
# tt_010a                       NaN          NaN          NaN
# tt_010a                       NaN          NaN          NaN
# tt_010a                       NaN          NaN          NaN
# tt_010a                       NaN          NaN          NaN
#
#                               name         set  \
# 0                    Astral Portal        KARA
# 1                Ancient Teachings     EXPERT1
# 2               Druid of the Flame         BRM
# 3               Justicar Trueheart         TGT
# 4                Faceless Behemoth          OG
# 5                        Rob Pardo     CREDITS
# 6               Eve of Destruction          OG
# 7               General Drakkisath         BRM
# 8                       Shrink Ray         GVG
# 9                          Harvest          TB
# 10                  Eydis Darkbane         TGT
# 11                        Enhanced        CORE
# 12             Trogg Hate Minions!         LOE
# 13                        Tank Up!  HERO_SKINS
# 14                       Smuggling       GANGS
# 15              Priestess of Elune     EXPERT1
# 16              Dire Fate: Murlocs          TB
# 17                         Cursed!         LOE
# 18                 Weasel Tunneler       GANGS
# 19                  Dragon Consort         BRM
# 20                     I Am Murloc       PROMO
# 21                 Chromatic Drake         BRM
# 22         Vaelastrasz the Corrupt         BRM
# 23                          Evolve          OG
# 24                     Anub'Rekhan        NAXX
# 25               Anodized Robo Cub         GVG
# 26                  Felfire Potion       GANGS
# 27                     Steady Shot  HERO_SKINS
# 28           Venture Co. Mercenary     EXPERT1
# 29           Netherspite Historian        KARA
# ...                            ...         ...
# OG_338                         NaN         NaN
# OG_338                         NaN         NaN
# OG_339                         NaN         NaN
# OG_339                         NaN         NaN
# OG_339                         NaN         NaN
# OG_339                         NaN         NaN
# OG_340                         NaN         NaN
# OG_340                         NaN         NaN
# OG_340                         NaN         NaN
# OG_340                         NaN         NaN
# TB_OG_027                      NaN         NaN
# TB_OG_027                      NaN         NaN
# TB_OG_027                      NaN         NaN
# TB_OG_027                      NaN         NaN
# skele21                        NaN         NaN
# skele21                        NaN         NaN
# skele21                        NaN         NaN
# skele21                        NaN         NaN
# tt_004                         NaN         NaN
# tt_004                         NaN         NaN
# tt_004                         NaN         NaN
# tt_004                         NaN         NaN
# tt_010                         NaN         NaN
# tt_010                         NaN         NaN
# tt_010                         NaN         NaN
# tt_010                         NaN         NaN
# tt_010a                        NaN         NaN
# tt_010a                        NaN         NaN
# tt_010a                        NaN         NaN
# tt_010a                        NaN         NaN
#
#                                                         text  cost  attack  \
# 0                   Summon a random <b>Legendary</b> minion.   1.0     NaN
# 1                                               Draw a card.   0.0     NaN
# 2                                                        NaN   3.0     2.0
# 3          <b>Battlecry:</b> Replace your starting Hero P...   6.0     6.0
# 4                                                        NaN  10.0    10.0
# 5          You can't start a game without this minion in ...   9.0     9.0
# 6                                           Stats increased.   NaN     NaN
# 7                                                        NaN   NaN     NaN
# 8                                       -2 Attack this turn.   NaN     NaN
# 9          <b>Hero Power</b>\nDraw a card. Gain a Mana Cr...   2.0     NaN
# 10         Whenever <b>you</b> target this minion with a ...   3.0     3.0
# 11            Raid Leader is granting this minion +1 Attack.   NaN     NaN
# 12         <b>Passive Hero Power</b>\n Enemy minions cost...   0.0     NaN
# 13                          <b>Hero Power</b>\nGain 4 Armor.   2.0     NaN
# 14                              +2/+2 from Smuggler's Crate.   NaN     NaN
# 15          <b>Battlecry:</b> Restore 4 Health to your hero.   6.0     5.0
# 16               Turn each minion in play into a 1/1 Murloc.   0.0     NaN
# 17         While this is in your hand, take 2 damage at t...   2.0     NaN
# 18         <b>Deathrattle:</b> Shuffle this minion into y...   1.0     1.0
# 19         <b>Battlecry:</b> The next Dragon you play cos...   5.0     5.0
# 20                  Summon three, four, or five 1/1 Murlocs.   4.0     NaN
# 21                                                       NaN   4.0     7.0
# 22                                                       NaN   NaN     NaN
# 23         Transform your minions into random minions tha...   1.0     NaN
# 24                                                       NaN   NaN     NaN
# 25         <b>Taunt</b>. <b>Choose One -</b>\n+1 Attack; ...   2.0     2.0
# 26                         Deal $5 damage to all characters.   6.0     NaN
# 27         <b>Hero Power</b>\nDeal $2 damage to the enemy...   2.0     NaN
# 28                               Your minions cost (3) more.   5.0     7.0
# 29         <b>Battlecry:</b> If you're holding a Dragon, ...   2.0     1.0
# ...                                                      ...   ...     ...
# OG_338                                                   NaN   NaN     NaN
# OG_338                                                   NaN   NaN     NaN
# OG_339                                                   NaN   NaN     NaN
# OG_339                                                   NaN   NaN     NaN
# OG_339                                                   NaN   NaN     NaN
# OG_339                                                   NaN   NaN     NaN
# OG_340                                                   NaN   NaN     NaN
# OG_340                                                   NaN   NaN     NaN
# OG_340                                                   NaN   NaN     NaN
# OG_340                                                   NaN   NaN     NaN
# TB_OG_027                                                NaN   NaN     NaN
# TB_OG_027                                                NaN   NaN     NaN
# TB_OG_027                                                NaN   NaN     NaN
# TB_OG_027                                                NaN   NaN     NaN
# skele21                                                  NaN   NaN     NaN
# skele21                                                  NaN   NaN     NaN
# skele21                                                  NaN   NaN     NaN
# skele21                                                  NaN   NaN     NaN
# tt_004                                                   NaN   NaN     NaN
# tt_004                                                   NaN   NaN     NaN
# tt_004                                                   NaN   NaN     NaN
# tt_004                                                   NaN   NaN     NaN
# tt_010                                                   NaN   NaN     NaN
# tt_010                                                   NaN   NaN     NaN
# tt_010                                                   NaN   NaN     NaN
# tt_010                                                   NaN   NaN     NaN
# tt_010a                                                  NaN   NaN     NaN
# tt_010a                                                  NaN   NaN     NaN
# tt_010a                                                  NaN   NaN     NaN
# tt_010a                                                  NaN   NaN     NaN
#
#            health     rarity    ...     \
# 0             NaN        NaN    ...
# 1             NaN        NaN    ...
# 2             5.0     COMMON    ...
# 3             3.0  LEGENDARY    ...
# 4            10.0     COMMON    ...
# 5             9.0  LEGENDARY    ...
# 6             NaN        NaN    ...
# 7            50.0        NaN    ...
# 8             NaN        NaN    ...
# 9             NaN        NaN    ...
# 10            4.0  LEGENDARY    ...
# 11            NaN        NaN    ...
# 12            NaN        NaN    ...
# 13            NaN        NaN    ...
# 14            NaN        NaN    ...
# 15            4.0     COMMON    ...
# 16            NaN        NaN    ...
# 17            NaN        NaN    ...
# 18            1.0       EPIC    ...
# 19            5.0       RARE    ...
# 20            NaN        NaN    ...
# 21            7.0        NaN    ...
# 22           30.0        NaN    ...
# 23            NaN       RARE    ...
# 24           30.0        NaN    ...
# 25            2.0     COMMON    ...
# 26            NaN       RARE    ...
# 27            NaN       FREE    ...
# 28            6.0     COMMON    ...
# 29            3.0     COMMON    ...
# ...           ...        ...    ...
# OG_338        NaN        NaN    ...
# OG_338        NaN        NaN    ...
# OG_339        NaN        NaN    ...
# OG_339        NaN        NaN    ...
# OG_339        NaN        NaN    ...
# OG_339        NaN        NaN    ...
# OG_340        NaN        NaN    ...
# OG_340        NaN        NaN    ...
# OG_340        NaN        NaN    ...
# OG_340        NaN        NaN    ...
# TB_OG_027     NaN        NaN    ...
# TB_OG_027     NaN        NaN    ...
# TB_OG_027     NaN        NaN    ...
# TB_OG_027     NaN        NaN    ...
# skele21       NaN        NaN    ...
# skele21       NaN        NaN    ...
# skele21       NaN        NaN    ...
# skele21       NaN        NaN    ...
# tt_004        NaN        NaN    ...
# tt_004        NaN        NaN    ...
# tt_004        NaN        NaN    ...
# tt_004        NaN        NaN    ...
# tt_010        NaN        NaN    ...
# tt_010        NaN        NaN    ...
# tt_010        NaN        NaN    ...
# tt_010        NaN        NaN    ...
# tt_010a       NaN        NaN    ...
# tt_010a       NaN        NaN    ...
# tt_010a       NaN        NaN    ...
# tt_010a       NaN        NaN    ...
#
#                                                       flavor        race  \
# 0                                                        NaN         NaN
# 1                                                        NaN         NaN
# 2                                                        NaN       BEAST
# 3          It's like putting racing stripes and a giant s...         NaN
# 4          Rejected names: Forty-Foot Faceless, Big ol' N...         NaN
# 5                                                        NaN         NaN
# 6                                                        NaN         NaN
# 7                                                        NaN         NaN
# 8                                                        NaN         NaN
# 9                                                        NaN         NaN
# 10                    HATES being called "the wonder twins".         NaN
# 11                                                       NaN         NaN
# 12                                                       NaN         NaN
# 13                                                       NaN         NaN
# 14                                                       NaN         NaN
# 15         If she threatens to "moon" you, it's not what ...         NaN
# 16                                                       NaN         NaN
# 17                                                       NaN         NaN
# 18         He's the reason the First Bank of Gadgetzan ha...       BEAST
# 19         Everybody wants someone to snuggle with. Even ...      DRAGON
# 20                                                       NaN         NaN
# 21                                                       NaN      DRAGON
# 22                                                       NaN         NaN
# 23         So you say you want an evolution. Well, you kn...         NaN
# 24                                                       NaN         NaN
# 25         It's adorable! AND OH MY GOODNESS WHY IS IT EA...  MECHANICAL
# 26         Kazakus has a squad of imps bottling Felfire r...         NaN
# 27                                                       NaN         NaN
# 28                    No Job is too big.  No fee is too big.         NaN
# 29         She can tell you all about the history of peop...         NaN
# ...                                                      ...         ...
# OG_338                                                   NaN         NaN
# OG_338                                                   NaN         NaN
# OG_339                                                   NaN         NaN
# OG_339                                                   NaN         NaN
# OG_339                                                   NaN         NaN
# OG_339                                                   NaN         NaN
# OG_340                                                   NaN         NaN
# OG_340                                                   NaN         NaN
# OG_340                                                   NaN         NaN
# OG_340                                                   NaN         NaN
# TB_OG_027                                                NaN         NaN
# TB_OG_027                                                NaN         NaN
# TB_OG_027                                                NaN         NaN
# TB_OG_027                                                NaN         NaN
# skele21                                                  NaN         NaN
# skele21                                                  NaN         NaN
# skele21                                                  NaN         NaN
# skele21                                                  NaN         NaN
# tt_004                                                   NaN         NaN
# tt_004                                                   NaN         NaN
# tt_004                                                   NaN         NaN
# tt_004                                                   NaN         NaN
# tt_010                                                   NaN         NaN
# tt_010                                                   NaN         NaN
# tt_010                                                   NaN         NaN
# tt_010                                                   NaN         NaN
# tt_010a                                                  NaN         NaN
# tt_010a                                                  NaN         NaN
# tt_010a                                                  NaN         NaN
# tt_010a                                                  NaN         NaN
#
#                                                  how_to_earn  \
# 0                                                        NaN
# 1                                                        NaN
# 2                                                        NaN
# 3                                                        NaN
# 4                                                        NaN
# 5                                                        NaN
# 6                                                        NaN
# 7                                                        NaN
# 8                                                        NaN
# 9                                                        NaN
# 10                                                       NaN
# 11                                                       NaN
# 12                                                       NaN
# 13                                                       NaN
# 14                                                       NaN
# 15                                                       NaN
# 16                                                       NaN
# 17                                                       NaN
# 18                                                       NaN
# 19         Unlocked in Blackrock Spire, in the Blackrock ...
# 20                                                       NaN
# 21                                                       NaN
# 22                                                       NaN
# 23                                                       NaN
# 24                                                       NaN
# 25                                                       NaN
# 26                                                       NaN
# 27                                                       NaN
# 28                                                       NaN
# 29          Unlocked in the Spire, in One Night in Karazhan.
# ...                                                      ...
# OG_338                                                   NaN
# OG_338                                                   NaN
# OG_339                                                   NaN
# OG_339                                                   NaN
# OG_339                                                   NaN
# OG_339                                                   NaN
# OG_340                                                   NaN
# OG_340                                                   NaN
# OG_340                                                   NaN
# OG_340                                                   NaN
# TB_OG_027                                                NaN
# TB_OG_027                                                NaN
# TB_OG_027                                                NaN
# TB_OG_027                                                NaN
# skele21                                                  NaN
# skele21                                                  NaN
# skele21                                                  NaN
# skele21                                                  NaN
# tt_004                                                   NaN
# tt_004                                                   NaN
# tt_004                                                   NaN
# tt_004                                                   NaN
# tt_010                                                   NaN
# tt_010                                                   NaN
# tt_010                                                   NaN
# tt_010                                                   NaN
# tt_010a                                                  NaN
# tt_010a                                                  NaN
# tt_010a                                                  NaN
# tt_010a                                                  NaN
#
#                                           how_to_earn_golden  \
# 0                                                        NaN
# 1                                                        NaN
# 2                                                        NaN
# 3                                                        NaN
# 4                                                        NaN
# 5                                                        NaN
# 6                                                        NaN
# 7                                                        NaN
# 8                                                        NaN
# 9                                                        NaN
# 10                                                       NaN
# 11                                                       NaN
# 12                                                       NaN
# 13                                                       NaN
# 14                                                       NaN
# 15                                                       NaN
# 16                                                       NaN
# 17                                                       NaN
# 18                                                       NaN
# 19         Crafting unlocked in Blackrock Spire, in the B...
# 20                                                       NaN
# 21                                                       NaN
# 22                                                       NaN
# 23                                                       NaN
# 24                                                       NaN
# 25                                                       NaN
# 26                                                       NaN
# 27                                                       NaN
# 28                                                       NaN
# 29         Crafting unlocked in the Spire, in One Night i...
# ...                                                      ...
# OG_338                                                   NaN
# OG_338                                                   NaN
# OG_339                                                   NaN
# OG_339                                                   NaN
# OG_339                                                   NaN
# OG_339                                                   NaN
# OG_340                                                   NaN
# OG_340                                                   NaN
# OG_340                                                   NaN
# OG_340                                                   NaN
# TB_OG_027                                                NaN
# TB_OG_027                                                NaN
# TB_OG_027                                                NaN
# TB_OG_027                                                NaN
# skele21                                                  NaN
# skele21                                                  NaN
# skele21                                                  NaN
# skele21                                                  NaN
# tt_004                                                   NaN
# tt_004                                                   NaN
# tt_004                                                   NaN
# tt_004                                                   NaN
# tt_010                                                   NaN
# tt_010                                                   NaN
# tt_010                                                   NaN
# tt_010                                                   NaN
# tt_010a                                                  NaN
# tt_010a                                                  NaN
# tt_010a                                                  NaN
# tt_010a                                                  NaN
#
#           targeting_arrow_text faction durability  card_id_dust  \
# 0                          NaN     NaN        NaN           NaN
# 1                          NaN     NaN        NaN           NaN
# 2                          NaN     NaN        NaN           NaN
# 3                          NaN     NaN        NaN           NaN
# 4                          NaN     NaN        NaN           NaN
# 5                          NaN     NaN        NaN           NaN
# 6                          NaN     NaN        NaN           NaN
# 7                          NaN     NaN        NaN           NaN
# 8                          NaN     NaN        NaN           NaN
# 9                          NaN     NaN        NaN           NaN
# 10                         NaN     NaN        NaN           NaN
# 11                         NaN     NaN        NaN           NaN
# 12                         NaN     NaN        NaN           NaN
# 13                         NaN     NaN        NaN           NaN
# 14                         NaN     NaN        NaN           NaN
# 15                         NaN     NaN        NaN           NaN
# 16                         NaN     NaN        NaN           NaN
# 17                         NaN     NaN        NaN           NaN
# 18                         NaN     NaN        NaN           NaN
# 19                         NaN     NaN        NaN           NaN
# 20                         NaN     NaN        NaN           NaN
# 21                         NaN     NaN        NaN           NaN
# 22                         NaN     NaN        NaN           NaN
# 23                         NaN     NaN        NaN           NaN
# 24                         NaN     NaN        NaN           NaN
# 25                         NaN     NaN        NaN           NaN
# 26                         NaN     NaN        NaN           NaN
# 27                         NaN     NaN        NaN           NaN
# 28                         NaN   HORDE        NaN           NaN
# 29                         NaN     NaN        NaN           NaN
# ...                        ...     ...        ...           ...
# OG_338                     NaN     NaN        NaN        OG_338
# OG_338                     NaN     NaN        NaN        OG_338
# OG_339                     NaN     NaN        NaN        OG_339
# OG_339                     NaN     NaN        NaN        OG_339
# OG_339                     NaN     NaN        NaN        OG_339
# OG_339                     NaN     NaN        NaN        OG_339
# OG_340                     NaN     NaN        NaN        OG_340
# OG_340                     NaN     NaN        NaN        OG_340
# OG_340                     NaN     NaN        NaN        OG_340
# OG_340                     NaN     NaN        NaN        OG_340
# TB_OG_027                  NaN     NaN        NaN     TB_OG_027
# TB_OG_027                  NaN     NaN        NaN     TB_OG_027
# TB_OG_027                  NaN     NaN        NaN     TB_OG_027
# TB_OG_027                  NaN     NaN        NaN     TB_OG_027
# skele21                    NaN     NaN        NaN       skele21
# skele21                    NaN     NaN        NaN       skele21
# skele21                    NaN     NaN        NaN       skele21
# skele21                    NaN     NaN        NaN       skele21
# tt_004                     NaN     NaN        NaN        tt_004
# tt_004                     NaN     NaN        NaN        tt_004
# tt_004                     NaN     NaN        NaN        tt_004
# tt_004                     NaN     NaN        NaN        tt_004
# tt_010                     NaN     NaN        NaN        tt_010
# tt_010                     NaN     NaN        NaN        tt_010
# tt_010                     NaN     NaN        NaN        tt_010
# tt_010                     NaN     NaN        NaN        tt_010
# tt_010a                    NaN     NaN        NaN       tt_010a
# tt_010a                    NaN     NaN        NaN       tt_010a
# tt_010a                    NaN     NaN        NaN       tt_010a
# tt_010a                    NaN     NaN        NaN       tt_010a
#
#                       action cost_dust
# 0                        NaN       NaN
# 1                        NaN       NaN
# 2                        NaN       NaN
# 3                        NaN       NaN
# 4                        NaN       NaN
# 5                        NaN       NaN
# 6                        NaN       NaN
# 7                        NaN       NaN
# 8                        NaN       NaN
# 9                        NaN       NaN
# 10                       NaN       NaN
# 11                       NaN       NaN
# 12                       NaN       NaN
# 13                       NaN       NaN
# 14                       NaN       NaN
# 15                       NaN       NaN
# 16                       NaN       NaN
# 17                       NaN       NaN
# 18                       NaN       NaN
# 19                       NaN       NaN
# 20                       NaN       NaN
# 21                       NaN       NaN
# 22                       NaN       NaN
# 23                       NaN       NaN
# 24                       NaN       NaN
# 25                       NaN       NaN
# 26                       NaN       NaN
# 27                       NaN       NaN
# 28                       NaN       NaN
# 29                       NaN       NaN
# ...                      ...       ...
# OG_338     DISENCHANT_NORMAL     400.0
# OG_338     DISENCHANT_GOLDEN    1600.0
# OG_339       CRAFTING_NORMAL     100.0
# OG_339       CRAFTING_GOLDEN     800.0
# OG_339     DISENCHANT_NORMAL      20.0
# OG_339     DISENCHANT_GOLDEN     100.0
# OG_340       CRAFTING_NORMAL    1600.0
# OG_340       CRAFTING_GOLDEN    3200.0
# OG_340     DISENCHANT_NORMAL     400.0
# OG_340     DISENCHANT_GOLDEN    1600.0
# TB_OG_027    CRAFTING_NORMAL     100.0
# TB_OG_027    CRAFTING_GOLDEN     800.0
# TB_OG_027  DISENCHANT_NORMAL      20.0
# TB_OG_027  DISENCHANT_GOLDEN     100.0
# skele21      CRAFTING_NORMAL      40.0
# skele21      CRAFTING_GOLDEN     400.0
# skele21    DISENCHANT_NORMAL       5.0
# skele21    DISENCHANT_GOLDEN      50.0
# tt_004       CRAFTING_NORMAL      40.0
# tt_004       CRAFTING_GOLDEN     400.0
# tt_004     DISENCHANT_NORMAL       5.0
# tt_004     DISENCHANT_GOLDEN      50.0
# tt_010       CRAFTING_NORMAL     400.0
# tt_010       CRAFTING_GOLDEN    1600.0
# tt_010     DISENCHANT_NORMAL     100.0
# tt_010     DISENCHANT_GOLDEN     400.0
# tt_010a      CRAFTING_NORMAL     400.0
# tt_010a      CRAFTING_GOLDEN    1600.0
# tt_010a    DISENCHANT_NORMAL     100.0
# tt_010a    DISENCHANT_GOLDEN     400.0
#
# [6859 rows x 21 columns]

# %% [markdown]
# Inspect the output above.  Note that the naming collision has been avoided by renaming the `cost` column from the right table to `cost_dust`.
#
# ## Summary
#
# In this lab, you learned how to:
#
# * Concatenate multiple DataFrames together into a single DataFrame
# * Understand and execute the various types of joins (inner, outer, left, and right joins)
